# %%
#!/usr/bin/env python
# coding:utf8

import codecs


import urllib.request as urlrequest
import json
import time
import random
from bs4 import BeautifulSoup

inputFile = 'douban_movie.txt'
fr = open(inputFile, 'r',encoding="utf8")
outputFile = 'douban_movie_detail.txt'
fw = open(outputFile, 'w')
fw.write('id^title^url^cover^rate^director^composer^actor^category^district^language^showtime^length^othername^description\n')

headers = {}
# headers["Accept"] = "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"
# headers["Accept-Encoding"] = "gzip, deflate, sdch"
# headers["Accept-Language"] = "zh-CN,zh;q=0.8,en;q=0.6,zh-TW;q=0.4,ja;q=0.2"
# headers["Cache-Control"] = "max-age=0"
# headers["Connection"] = "keep-alive"
# headers["Cookie"] = 'asdasd13323efafasfa'
# headers["Host"] = "movie.douban.com"
# headers["Referer"] = "http://movie.douban.com/"
# headers["Upgrade-Insecure-Requests"] = 1
headers["User-Agent"] = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"

firstLine = True

count = 1

errorCount = 0

result = {}

for line in fr:
	if firstLine:
		firstLine = False
		continue

	line = line.split(';')

	movieId = line[0]
	title = line[1]
	url = line[2]
	cover = line[3]
	rate = line[4].rstrip('\n')

	if result.__contains__(movieId):
		continue
	else:
		result[str(movieId)] = 1

	try:
		request = urlrequest.Request(url=url,headers=headers)
		# request = urllib2.Request(url=url)
		response = urlrequest.urlopen(request)
		html = response.read()
		html = BeautifulSoup(html)

		info = html.select('#info')[0]
		info = info.get_text().split('\n')

		# 提取字段，只要冒号后面的文本内容
		director = info[1].split(':')[-1].strip()
		composer = info[2].split(':')[-1].strip()
		actor = info[3].split(':')[-1].strip()
		category = info[4].split(':')[-1].strip()
		district = info[6].split(':')[-1].strip()
		language = info[7].split(':')[-1].strip()
		showtime = info[8].split(':')[-1].strip()
		length = info[9].split(':')[-1].strip()
		othername = info[10].split(':')[-1].strip()

		# 电影简介
		description = html.find_all("span", attrs={"property": "v:summary"})[0].get_text()
		description = description.lstrip().lstrip('\n\t').rstrip().rstrip('\n\t').replace('\n','\t')

		# 写入数据
		record = str(movieId) + '^' + str(title) + '^' + str(url) + '^' + str(cover) + '^' + str(rate) + '^' + director.encode('utf8') + '^' + composer.encode('utf8') + '^' + actor.encode('utf8') + '^' + category.encode('utf8') + '^' + district.encode('utf8') + '^' + language.encode('utf8') + '^' + showtime.encode('utf8') + '^' + length.encode('utf8') + '^' + othername.encode('utf8') + '^' + description.encode('utf8') + '\n'
		fw.write(record)
		print (count,title)
		time.sleep(5)
	
	except Exception as  e:
		print (e)
		print (count,title,"Error")
		errorCount = errorCount + 1
	else:
		pass
	finally:
		pass

	count = count + 1
	
print (count, errorCount)
fr.close()
fw.close()
# Out:
# C:\Users\tianjiayang\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\tianjiayang\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# list index out of range
# 1 我是路人甲 Error
# list index out of range
# 2 铁拳 Error
# list index out of range
# 3 我们梦中见 Error
# list index out of range
# 4 少年透明人 Error
# list index out of range
# 5 撒迦利亚 Error
# list index out of range
# 6 非我 Error
# list index out of range
# 7 唇上之歌 Error
# list index out of range
# 8 如晴天，似雨天 Error
# list index out of range
# 9 故事的故事 Error
# list index out of range
# 10 奸臣 Error
# list index out of range
# 11 头脑特工队 Error
# list index out of range
# 12 小森林 冬春篇 Error
# list index out of range
# 13 小男孩 Error
# list index out of range
# 14 可爱的你 Error
# list index out of range
# 15 花与爱丽丝杀人事件 Error
# list index out of range
# 16 百元之恋 Error
# list index out of range
# 17 少年班 Error
# list index out of range
# 18 末日崩塌 Error
# list index out of range
# 19 深夜食堂 电影版 Error
# list index out of range
# 20 冲出康普顿 Error
# list index out of range
# 21 魔力麦克2 Error
# list index out of range
# 22 谜城 Error
# list index out of range
# 23 模仿游戏 Error
# list index out of range
# 24 小羊肖恩 Error
# list index out of range
# 25 进击的巨人真人版：前篇 Error
# list index out of range
# 26 女间谍 Error
# list index out of range
# 27 爆裂鼓手 Error
# list index out of range
# 28 杀破狼2 Error
# list index out of range
# 29 道士下山 Error
# list index out of range
# 30 我是谁：没有绝对安全的系统 Error
# list index out of range
# 31 贝利叶一家 Error
# list index out of range
# 32 疯狂的麦克斯4：狂暴之路 Error
# list index out of range
# 33 时光尽头的恋人 Error
# list index out of range
# 34 坏姐姐之拆婚联盟 Error
# list index out of range
# 35 嘘！禁止想象！ Error
# list index out of range
# 36 机械姬 Error
# list index out of range
# 37 栀子花开 Error
# list index out of range
# 38 复仇者联盟2：奥创纪元 Error
# list index out of range
# 39 工作女郎 Error
# list index out of range
# 40 少女哪吒 Error
# list index out of range
# 41 我的个神啊 Error
# list index out of range
# 42 左耳 Error
# list index out of range
# 43 对风说爱你 Error
# list index out of range
# 44 小时代4：灵魂尽头 Error
# list index out of range
# 45 消失的爱人 Error
# list index out of range
# 46 暗黑之地 Error
# list index out of range
# 47 麦克法兰 Error
# list index out of range
# 48 风流艳妇 Error
# list index out of range
# 49 念念 Error
# list index out of range
# 50 速度与激情7 Error
# list index out of range
# 51 王牌特工：特工学院 Error
# list index out of range
# 52 泰迪熊2 Error
# list index out of range
# 53 远离尘嚣 Error
# list index out of range
# 54 新步步惊心 Error
# list index out of range
# 55 国际市场 Error
# list index out of range
# 56 重返20岁 Error
# list index out of range
# 57 分歧者2：绝地反击 Error
# list index out of range
# 58 最长的旅程 Error
# list index out of range
# 59 阿罗哈 Error
# list index out of range
# 60 暴疯语 Error
# list index out of range
# 61 美国狙击手 Error
# list index out of range
# 62 味园Universe Error
# list index out of range
# 63 寄生兽 Error
# list index out of range
# 64 中国之旅 Error
# list index out of range
# 65 疯狂外星人 Error
# list index out of range
# 66 控制游戏 Error
# list index out of range
# 67 超能查派 Error
# list index out of range
# 68 所罗门的伪证前篇：事件 Error
# list index out of range
# 69 星际穿越 Error
# list index out of range
# 70 天将雄师 Error
# list index out of range
# 71 冲锋车 Error
# list index out of range
# 72 霍比特人3：五军之战 Error
# list index out of range
# 73 金衣女人 Error
# list index out of range
# 74 无人引航 Error
# list index out of range
# 75 侏罗纪世界 Error
# list index out of range
# 76 帕丁顿熊 Error
# list index out of range
# 77 超能陆战队 Error
# list index out of range
# 78 赤道 Error
# list index out of range
# 79 有一个地方只有我们知道 Error
# list index out of range
# 80 男人与鸡 Error
# list index out of range
# 81 博物馆奇妙夜3 Error
# list index out of range
# 82 44号孩子 Error
# list index out of range
# 83 万物生长 Error
# list index out of range
# 84 0.5毫米 Error
# list index out of range
# 85 鸭王 Error
# list index out of range
# 86 战狼 Error
# list index out of range
# 87 爱你，罗茜 Error
# list index out of range
# 88 江南1970 Error
# list index out of range
# 89 第七子：降魔之战 Error
# list index out of range
# 90 军犬麦克斯 Error
# list index out of range
# 91 一步之遥 Error
# list index out of range
# 92 生活残骸 Error
# list index out of range
# 93 海月姬 Error
# list index out of range
# 94 雏妓 Error
# list index out of range
# 95 灰姑娘 Error
# list index out of range
# 96 横冲直撞好莱坞 Error
# list index out of range
# 97 涉足荒野 Error
# list index out of range
# 98 所罗门的伪证后篇：审判 Error
# list index out of range
# 99 命中注定 Error
# list index out of range
# 100 何以笙箫默 Error
# list index out of range
# 101 许三观 Error
# list index out of range
# 102 午夜邂逅 Error
# list index out of range
# 103 贵族大盗 Error
# list index out of range
# 104 智取威虎山 Error
# list index out of range
# 105 木星上行 Error
# list index out of range
# 106 我是女王 Error
# list index out of range
# 107 爱的那点性事 Error
# list index out of range
# 108 西部慢调 Error
# list index out of range
# 109 暴走神探 Error
# list index out of range
# 110 客人 Error
# list index out of range
# 111 完美音调2 Error
# list index out of range
# 112 饥饿游戏3：嘲笑鸟(上) Error
# list index out of range
# 113 二十 Error
# list index out of range
# 114 失孤 Error
# list index out of range
# 115 坚不可摧 Error
# list index out of range
# 116 测试 Error
# list index out of range
# 117 七日地狱 Error
# list index out of range
# 118 明星伙伴 Error
# list index out of range
# 119 钟馗伏魔：雪妖魔灵 Error
# list index out of range
# 120 太平轮(上) Error
# list index out of range
# 121 少数意见 Error
# list index out of range
# 122 爱情限时恋未尽 Error
# list index out of range
# 123 十万个冷笑话 Error
# list index out of range
# 124 海绵宝宝历险记：海绵出水 Error
# list index out of range
# 125 狂怒 Error
# list index out of range
# 126 长寿商会 Error
# list index out of range
# 127 飓风营救3 Error
# list index out of range
# 128 要听神明的话 Error
# list index out of range
# 129 缄默的迷宫 Error
# list index out of range
# 130 通灵之六世古宅 Error
# list index out of range
# 131 北京纽约 Error
# list index out of range
# 132 我们假期做了什么 Error
# list index out of range
# 133 伸冤人 Error
# list index out of range
# 134 焦点 Error
# list index out of range
# 135 新女友 Error
# list index out of range
# 136 鬼牌游戏 Error
# list index out of range
# 137 大眼睛 Error
# list index out of range
# 138 小混乱 Error
# list index out of range
# 139 麦兜我和我妈妈 Error
# list index out of range
# 140 珍妮的婚礼 Error
# list index out of range
# 141 咱们结婚吧 Error
# list index out of range
# 142 冲上云霄 Error
# list index out of range
# 143 匆匆那年 Error
# list index out of range
# 144 塞尔玛 Error
# list index out of range
# 145 法老与众神 Error
# list index out of range
# 146 魔法黑森林 Error
# list index out of range
# 147 1944 Error
# list index out of range
# 148 烈性摔跤 Error
# list index out of range
# 149 再见我们的十年 Error
# list index out of range
# 150 法国战恋曲 Error
# list index out of range
# 151 微爱之渐入佳境 Error
# list index out of range
# 152 真幌站前狂想曲 Error
# list index out of range
# 153 青春之旅 真人版 Error
# list index out of range
# 154 潜伏3 Error
# list index out of range
# 155 布拉芙夫人 Error
# list index out of range
# 156 花宵道中 Error
# list index out of range
# 157 移动迷宫 Error
# list index out of range
# 158 暗夜逐仇 Error
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-22cd5497c370> in <module>()
#      58                 request = urlrequest.Request(url=url,headers=headers)
#      59                 # request = urllib2.Request(url=url)
# ---> 60                 response = urlrequest.urlopen(request)
#      61                 html = response.read()
#      62                 html = BeautifulSoup(html)
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1284
#    1285         # will parse host:port
# -> 1286         h = http_class(host, timeout=req.timeout, **http_conn_args)
#    1287         h.set_debuglevel(self._debuglevel)
#    1288
#
# ~\Anaconda3\lib\http\client.py in __init__(self, host, port, key_file, cert_file, timeout, source_address, context, check_hostname)
#    1375             self.cert_file = cert_file
#    1376             if context is None:
# -> 1377                 context = ssl._create_default_https_context()
#    1378             will_verify = context.verify_mode != ssl.CERT_NONE
#    1379             if check_hostname is None:
#
# ~\Anaconda3\lib\ssl.py in create_default_context(purpose, cafile, capath, cadata)
#     515         # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     516         # root CA certificates for the given purpose. This may fail silently.
# --> 517         context.load_default_certs(purpose)
#     518     return context
#     519
#
# KeyboardInterrupt:
